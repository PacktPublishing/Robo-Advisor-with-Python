# %% [markdown]
# # Chapter 5: Basic Setup

# %%
# !pip install PyPortfolioOpt==1.4.1

from pypfopt.efficient_frontier import EfficientFrontier
# Out:
# Requirement already satisfied: PyPortfolioOpt==1.4.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from PyPortfolioOpt==1.4.1) (1.3.5)
# Requirement already satisfied: scipy<2.0,>=1.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from PyPortfolioOpt==1.4.1) (1.9.3)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.10 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from PyPortfolioOpt==1.4.1) (1.3.0)
# Requirement already satisfied: numpy<2.0,>=1.12 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from PyPortfolioOpt==1.4.1) (1.23.5)
# Requirement already satisfied: scs>=1.1.6 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt==1.4.1) (3.2.2)
# Requirement already satisfied: ecos>=2 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt==1.4.1) (2.0.12)
# Requirement already satisfied: osqp>=0.4.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt==1.4.1) (0.6.2.post8)
# Requirement already satisfied: setuptools<=64.0.2 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt==1.4.1) (64.0.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas>=0.19->PyPortfolioOpt==1.4.1) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas>=0.19->PyPortfolioOpt==1.4.1) (2.8.1)
# Requirement already satisfied: qdldl in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.10->PyPortfolioOpt==1.4.1) (0.1.5.post3)
# Requirement already satisfied: six>=1.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt==1.4.1) (1.16.0)
# (CVXPY) Jan 25 03:52:43 PM: Encountered unexpected exception importing solver ECOS:
# ImportError("dlopen(/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so, 0x0002): tried: '/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so' (no such file), '/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64'))")
# (CVXPY) Jan 25 03:52:43 PM: Encountered unexpected exception importing solver SCS:
# ImportError("dlopen(/Users/akiranin/miniforge3/lib/python3.10/site-packages/_scs_direct.cpython-310-darwin.so, 0x0002): tried: '/Users/akiranin/miniforge3/lib/python3.10/site-packages/_scs_direct.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/akiranin/miniforge3/lib/python3.10/site-packages/_scs_direct.cpython-310-darwin.so' (no such file), '/Users/akiranin/miniforge3/lib/python3.10/site-packages/_scs_direct.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64'))")
# (CVXPY) Jan 25 03:52:50 PM: Encountered unexpected exception importing solver ECOS_BB:
# ImportError("dlopen(/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so, 0x0002): tried: '/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so' (no such file), '/Users/akiranin/miniforge3/lib/python3.10/site-packages/_ecos.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64'))")
# (CVXPY) Jan 25 03:52:50 PM: Encountered unexpected exception importing solver OSQP:
# ImportError("dlopen(/Users/akiranin/miniforge3/lib/python3.10/site-packages/qdldl.cpython-310-darwin.so, 0x0002): tried: '/Users/akiranin/miniforge3/lib/python3.10/site-packages/qdldl.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/akiranin/miniforge3/lib/python3.10/site-packages/qdldl.cpython-310-darwin.so' (no such file), '/Users/akiranin/miniforge3/lib/python3.10/site-packages/qdldl.cpython-310-darwin.so' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64'))")

# %%
# !pip install yfinance --upgrade
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in /Users/akiranin/miniforge3/lib/python3.10/site-packages (0.2.4)
# Collecting yfinance
#   Downloading yfinance-0.2.6-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 352.6 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: multitasking>=0.0.7 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: html5lib>=1.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: pandas>=1.3.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (1.3.5)
# Requirement already satisfied: pytz>=2022.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (39.0.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (1.24.1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from yfinance) (2.28.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: pycparser in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.4
#     Uninstalling yfinance-0.2.4:
#       Successfully uninstalled yfinance-0.2.4
# Successfully installed yfinance-0.2.6

# %%
msft = yf.Ticker("MSFT")
hist = msft.history(period="max")

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas_datareader) (1.3.5)
# Requirement already satisfied: lxml in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas_datareader) (4.9.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas>=0.23->pandas_datareader) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas>=0.23->pandas_datareader) (1.23.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->pandas_datareader) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->pandas_datareader) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->pandas_datareader) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.13)
# Requirement already satisfied: six>=1.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.16.0)
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.10.0

# %%
from pandas_datareader import data as pdr
yf.pdr_override() # <== that's all it takes :-)

data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install mplfinance
import mplfinance as mpf

mpf.plot(hist,type='line')
mpf.plot(data,type='line')
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.9b7-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from mplfinance) (3.6.2)
# Requirement already satisfied: pandas in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from mplfinance) (1.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (22.0)
# Requirement already satisfied: numpy>=1.19 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from pandas->mplfinance) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/akiranin/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.9b7
